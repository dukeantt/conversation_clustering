# %%
import plotly.graph_objects as go
import plotly.express as px
import pandas as pd

df = pd.read_csv("data/tsne_vectors_3d_input_text_only.csv")

fig = px.scatter_3d(
    df,
    x='x',
    y='y',
    z='z',
    color="kmeans_cluster",
    hover_data=["short_input_texts", "short_bot_texts","intent","short_entities","action_1"],
    )

fig.show()

x = 0
# Out:
# <div>
#
#
#             <div id="c7e46f8f-c685-41a2-b0eb-20a4b48b8bc8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c7e46f8f-c685-41a2-b0eb-20a4b48b8bc8")) {
#                     Plotly.newPlot(
#                         'c7e46f8f-c685-41a2-b0eb-20a4b48b8bc8',
#                         [{"customdata": [["m\u00e1y ti\u1ec7t tr\u00f9ng uv \u0111\u00e3 c\u00f3 ch\u01b0a \u1ea1", "Hi\u1ec7n t\u1ea1i s\u1ea3n ph\u1ea9m M\u00e1y ti\u1ec7t tr\u00f9ng  shop \u0111ang c\u00f3 nh\u1eef-<br>", "query_knowledge_base", "['object_type:may_tiet_trung']", "action_query_babe_kb"], ["/confirm_attribute_value{\"price\": \"500-1M\"}", "M\u1eddi b\u1ea1n click v\u00e0o \"Xem chi ti\u1ebft\" \u0111\u1ec3 tham kh\u1ea3o s\u1ea3n -<br> ph\u1ea9m hi\u1ec7n c\u00f3 t\u1ea1i shop nh\u00e9!\n<card sp 1> <card sp 2>-<br>", "confirm_attribute_value", "['price:500-1M']", "action_query_babe_kb"], ["m\u00e1y ti\u1ec7t tr\u00f9ng uv \u0111\u00e3 c\u00f3 ch\u01b0a \u1ea1", "M\u00e1y ti\u1ec7t tr\u00f9ng uv hi\u1ec7n h\u1ebft h\u00e0ng m\u1eddi b\u1ea1n tham kh\u1ea3o -<br> c\u00e1c s\u1ea3n ph\u1ea9m kh\u00e1c c\u1ee7a shop\nRecommend <sp1> <sp2> <-<br>", "query_knowledge_base", "['object_type:may_tiet_trung']", "action_query_babe_kb"], ["Khi n\u00e0o th\u00ec c\u00f3 h\u00e0ng m\u1edbi \u1ea1", "Kho\u1ea3ng m\u1ed9t tu\u1ea7n sau c\u00f3 h\u00e0ng \u1ea1", "query_knowledge_base", null, "action_query_babe_kb"], ["url", "B\u1ea1n \u0111ang t\u00ecm ki\u1ebfm th\u00f4ng tin g\u00ec \u1ea1?", "send_link", "url", "action_handle_send_link_only"], ["E \u01a1i c\u00f2n gi\u1ea5y kh\u00f4 n\u00e0y k?", "Kh\u0103n kh\u00f4 \u0111a n\u0103ng MIPBI 600gr hi\u1ec7n \u0111ang c\u00f3 gi\u00e1 l\u00e0 6-<br> 1.000 (Gi\u00e1 g\u1ed1c: 70.000) m\u1eddi b\u1ea1n tham kh\u1ea3o:\n<show c-<br>", "query_knowledge_base", "['object_type:khan','mention:n\u00e0y']", "action_query_babe_kb"], ["\u0110\u00fang r \u1ea1", "D\u1ea1, v\u00e2ng \u1ea1. ", "agree", null, "utter_agree"], ["url", "B\u1ea1n \u0111ang t\u00ecm ki\u1ebfm th\u00f4ng tin g\u00ec \u1ea1?", "send_link", "url", "action_handle_send_link_only"], ["E \u01a1i c\u00f2n gi\u1ea5y kh\u00f4 n\u00e0y k?", "Kh\u0103n kh\u00f4 \u0111a n\u0103ng MIPBI 600gr  hi\u1ec7n h\u1ebft h\u00e0ng m\u1eddi b\u1ea1-<br> n tham kh\u1ea3o c\u00e1c s\u1ea3n ph\u1ea9m kh\u00e1c c\u1ee7a shop\nRecommend <-<br>", "query_knowledge_base", "['object_type:khan','mention:n\u00e0y']", "action_query_babe_kb"], ["url", "B\u1ea1n \u0111ang t\u00ecm ki\u1ebfm th\u00f4ng tin g\u00ec \u1ea1?", "send_link", "url", "action_handle_send_link_only"], ["Bn v\u1eady shop \u01a1i", "S\u1ea3n ph\u1ea9m  B\u1ea2NG V\u1ebc HOLLA 2 in 1  hi\u1ec7n shop \u0111ang c\u00f3 -<br> gi\u00e1: 830,000 VND (gi\u00e1 g\u1ed1c 1,090,000 VND).\nB\u1ea1n tham-<br>", "query_knowledge_base", "['attribute:price']", "action_query_babe_kb"], ["C\u00f3 tr\u00ean shopee k shop", "D\u1ea1 m\u1eddi b\u1ea1n tham kh\u1ea3o s\u1ea3n ph\u1ea9m B\u1ea2NG V\u1ebc HOLLA 2 in 1-<br>", "query_knowledge_base", "['attribute:link']", "action_query_babe_kb"], ["url", "B\u1ea1n \u0111ang t\u00ecm ki\u1ebfm th\u00f4ng tin g\u00ec \u1ea1?", "send_link", "url", "action_handle_send_link_only"], ["Bn v\u1eady shop \u01a1i", "S\u1ea3n ph\u1ea9m  B\u1ea2NG V\u1ebc HOLLA 2 in 1  hi\u1ec7n shop \u0111ang c\u00f3 -<br> gi\u00e1: 830,000 VND (gi\u00e1 g\u1ed1c 1,090,000 VND).\nB\u1ea1n tham-<br>", "query_knowledge_base", "['attribute:price']", "action_query_babe_kb"], ["B\u1ea3o h\u00e0nh bao l\u00e2u \u1ea1", "\"D\u1ea1 B\u1ea2NG V\u1ebc HOLLA 2 in 1 b\u1ea3o h\u00e0nh 12 th\u00e1ng \u1ea1. {ch\u00ed-<br>", "query_knowledge_base", "['attribute:guarantee']", "action_query_babe_kb"], ["url", "B\u1ea1n \u0111ang t\u00ecm ki\u1ebfm th\u00f4ng tin g\u00ec \u1ea1?", "send_link", "url", "action_handle_send_link_only"], ["B\u1ed9 n\u00e0y bn shop", "S\u1ea3n ph\u1ea9m  B\u1ea2NG V\u1ebc HOLLA 2 in 1  hi\u1ec7n shop \u0111ang c\u00f3 -<br> gi\u00e1: 830,000 VND (gi\u00e1 g\u1ed1c 1,090,000 VND).\nB\u1ea1n tham-<br>", "query_knowledge_base", "['mention:b\u1ed9 n\u00e0y', 'attribute:price']", "action_query_babe_kb"], ["S\u1ea3n xu\u1ea5t \u1edf \u0111\u00e2u \u1ea1", "D\u1ea1 B\u1ea2NG V\u1ebc HOLLA 2 in 1 c\u00f3 xu\u1ea5t x\u1ee9 t\u1eeb Trung Qu\u1ed1c \u1ea1-<br>", "query_knowledg ...

# %%
fig = px.scatter_3d(
    df,
    x='x',
    y='y',
    z='z',
    color="gm_cluster",
    hover_data=["short_input_texts", "short_bot_texts","intent","short_entities","action_1"],
    )

fig.show()
# Out:
# <div>
#
#
#             <div id="a10c99b3-218d-42a6-82ac-1a4897b4011c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a10c99b3-218d-42a6-82ac-1a4897b4011c")) {
#                     Plotly.newPlot(
#                         'a10c99b3-218d-42a6-82ac-1a4897b4011c',
#                         [{"customdata": [["m\u00e1y ti\u1ec7t tr\u00f9ng uv \u0111\u00e3 c\u00f3 ch\u01b0a \u1ea1", "Hi\u1ec7n t\u1ea1i s\u1ea3n ph\u1ea9m M\u00e1y ti\u1ec7t tr\u00f9ng  shop \u0111ang c\u00f3 nh\u1eef-<br>", "query_knowledge_base", "['object_type:may_tiet_trung']", "action_query_babe_kb"], ["/confirm_attribute_value{\"price\": \"500-1M\"}", "M\u1eddi b\u1ea1n click v\u00e0o \"Xem chi ti\u1ebft\" \u0111\u1ec3 tham kh\u1ea3o s\u1ea3n -<br> ph\u1ea9m hi\u1ec7n c\u00f3 t\u1ea1i shop nh\u00e9!\n<card sp 1> <card sp 2>-<br>", "confirm_attribute_value", "['price:500-1M']", "action_query_babe_kb"], ["m\u00e1y ti\u1ec7t tr\u00f9ng uv \u0111\u00e3 c\u00f3 ch\u01b0a \u1ea1", "M\u00e1y ti\u1ec7t tr\u00f9ng uv hi\u1ec7n h\u1ebft h\u00e0ng m\u1eddi b\u1ea1n tham kh\u1ea3o -<br> c\u00e1c s\u1ea3n ph\u1ea9m kh\u00e1c c\u1ee7a shop\nRecommend <sp1> <sp2> <-<br>", "query_knowledge_base", "['object_type:may_tiet_trung']", "action_query_babe_kb"], ["Khi n\u00e0o th\u00ec c\u00f3 h\u00e0ng m\u1edbi \u1ea1", "Kho\u1ea3ng m\u1ed9t tu\u1ea7n sau c\u00f3 h\u00e0ng \u1ea1", "query_knowledge_base", null, "action_query_babe_kb"], ["url", "B\u1ea1n \u0111ang t\u00ecm ki\u1ebfm th\u00f4ng tin g\u00ec \u1ea1?", "send_link", "url", "action_handle_send_link_only"], ["E \u01a1i c\u00f2n gi\u1ea5y kh\u00f4 n\u00e0y k?", "Kh\u0103n kh\u00f4 \u0111a n\u0103ng MIPBI 600gr hi\u1ec7n \u0111ang c\u00f3 gi\u00e1 l\u00e0 6-<br> 1.000 (Gi\u00e1 g\u1ed1c: 70.000) m\u1eddi b\u1ea1n tham kh\u1ea3o:\n<show c-<br>", "query_knowledge_base", "['object_type:khan','mention:n\u00e0y']", "action_query_babe_kb"], ["\u0110\u00fang r \u1ea1", "D\u1ea1, v\u00e2ng \u1ea1. ", "agree", null, "utter_agree"], ["url", "B\u1ea1n \u0111ang t\u00ecm ki\u1ebfm th\u00f4ng tin g\u00ec \u1ea1?", "send_link", "url", "action_handle_send_link_only"], ["E \u01a1i c\u00f2n gi\u1ea5y kh\u00f4 n\u00e0y k?", "Kh\u0103n kh\u00f4 \u0111a n\u0103ng MIPBI 600gr  hi\u1ec7n h\u1ebft h\u00e0ng m\u1eddi b\u1ea1-<br> n tham kh\u1ea3o c\u00e1c s\u1ea3n ph\u1ea9m kh\u00e1c c\u1ee7a shop\nRecommend <-<br>", "query_knowledge_base", "['object_type:khan','mention:n\u00e0y']", "action_query_babe_kb"], ["url", "B\u1ea1n \u0111ang t\u00ecm ki\u1ebfm th\u00f4ng tin g\u00ec \u1ea1?", "send_link", "url", "action_handle_send_link_only"], ["Bn v\u1eady shop \u01a1i", "S\u1ea3n ph\u1ea9m  B\u1ea2NG V\u1ebc HOLLA 2 in 1  hi\u1ec7n shop \u0111ang c\u00f3 -<br> gi\u00e1: 830,000 VND (gi\u00e1 g\u1ed1c 1,090,000 VND).\nB\u1ea1n tham-<br>", "query_knowledge_base", "['attribute:price']", "action_query_babe_kb"], ["C\u00f3 tr\u00ean shopee k shop", "D\u1ea1 m\u1eddi b\u1ea1n tham kh\u1ea3o s\u1ea3n ph\u1ea9m B\u1ea2NG V\u1ebc HOLLA 2 in 1-<br>", "query_knowledge_base", "['attribute:link']", "action_query_babe_kb"], ["url", "B\u1ea1n \u0111ang t\u00ecm ki\u1ebfm th\u00f4ng tin g\u00ec \u1ea1?", "send_link", "url", "action_handle_send_link_only"], ["Bn v\u1eady shop \u01a1i", "S\u1ea3n ph\u1ea9m  B\u1ea2NG V\u1ebc HOLLA 2 in 1  hi\u1ec7n shop \u0111ang c\u00f3 -<br> gi\u00e1: 830,000 VND (gi\u00e1 g\u1ed1c 1,090,000 VND).\nB\u1ea1n tham-<br>", "query_knowledge_base", "['attribute:price']", "action_query_babe_kb"], ["B\u1ea3o h\u00e0nh bao l\u00e2u \u1ea1", "\"D\u1ea1 B\u1ea2NG V\u1ebc HOLLA 2 in 1 b\u1ea3o h\u00e0nh 12 th\u00e1ng \u1ea1. {ch\u00ed-<br>", "query_knowledge_base", "['attribute:guarantee']", "action_query_babe_kb"], ["url", "B\u1ea1n \u0111ang t\u00ecm ki\u1ebfm th\u00f4ng tin g\u00ec \u1ea1?", "send_link", "url", "action_handle_send_link_only"], ["B\u1ed9 n\u00e0y bn shop", "S\u1ea3n ph\u1ea9m  B\u1ea2NG V\u1ebc HOLLA 2 in 1  hi\u1ec7n shop \u0111ang c\u00f3 -<br> gi\u00e1: 830,000 VND (gi\u00e1 g\u1ed1c 1,090,000 VND).\nB\u1ea1n tham-<br>", "query_knowledge_base", "['mention:b\u1ed9 n\u00e0y', 'attribute:price']", "action_query_babe_kb"], ["S\u1ea3n xu\u1ea5t \u1edf \u0111\u00e2u \u1ea1", "D\u1ea1 B\u1ea2NG V\u1ebc HOLLA 2 in 1 c\u00f3 xu\u1ea5t x\u1ee9 t\u1eeb Trung Qu\u1ed1c \u1ea1-<br>", "query_knowledg ...

# %%
fig = px.scatter_3d(
    df,
    x='x',
    y='y',
    z='z',
    color="hc_cluster",
    hover_data=["short_input_texts", "short_bot_texts","intent","short_entities","action_1"],
    )

fig.show()
# Out:
# <div>
#
#
#             <div id="fac80a03-9a2c-4e99-8c26-97fa3a2e5f91" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("fac80a03-9a2c-4e99-8c26-97fa3a2e5f91")) {
#                     Plotly.newPlot(
#                         'fac80a03-9a2c-4e99-8c26-97fa3a2e5f91',
#                         [{"customdata": [["m\u00e1y ti\u1ec7t tr\u00f9ng uv \u0111\u00e3 c\u00f3 ch\u01b0a \u1ea1", "Hi\u1ec7n t\u1ea1i s\u1ea3n ph\u1ea9m M\u00e1y ti\u1ec7t tr\u00f9ng  shop \u0111ang c\u00f3 nh\u1eef-<br>", "query_knowledge_base", "['object_type:may_tiet_trung']", "action_query_babe_kb"], ["/confirm_attribute_value{\"price\": \"500-1M\"}", "M\u1eddi b\u1ea1n click v\u00e0o \"Xem chi ti\u1ebft\" \u0111\u1ec3 tham kh\u1ea3o s\u1ea3n -<br> ph\u1ea9m hi\u1ec7n c\u00f3 t\u1ea1i shop nh\u00e9!\n<card sp 1> <card sp 2>-<br>", "confirm_attribute_value", "['price:500-1M']", "action_query_babe_kb"], ["m\u00e1y ti\u1ec7t tr\u00f9ng uv \u0111\u00e3 c\u00f3 ch\u01b0a \u1ea1", "M\u00e1y ti\u1ec7t tr\u00f9ng uv hi\u1ec7n h\u1ebft h\u00e0ng m\u1eddi b\u1ea1n tham kh\u1ea3o -<br> c\u00e1c s\u1ea3n ph\u1ea9m kh\u00e1c c\u1ee7a shop\nRecommend <sp1> <sp2> <-<br>", "query_knowledge_base", "['object_type:may_tiet_trung']", "action_query_babe_kb"], ["Khi n\u00e0o th\u00ec c\u00f3 h\u00e0ng m\u1edbi \u1ea1", "Kho\u1ea3ng m\u1ed9t tu\u1ea7n sau c\u00f3 h\u00e0ng \u1ea1", "query_knowledge_base", null, "action_query_babe_kb"], ["url", "B\u1ea1n \u0111ang t\u00ecm ki\u1ebfm th\u00f4ng tin g\u00ec \u1ea1?", "send_link", "url", "action_handle_send_link_only"], ["E \u01a1i c\u00f2n gi\u1ea5y kh\u00f4 n\u00e0y k?", "Kh\u0103n kh\u00f4 \u0111a n\u0103ng MIPBI 600gr hi\u1ec7n \u0111ang c\u00f3 gi\u00e1 l\u00e0 6-<br> 1.000 (Gi\u00e1 g\u1ed1c: 70.000) m\u1eddi b\u1ea1n tham kh\u1ea3o:\n<show c-<br>", "query_knowledge_base", "['object_type:khan','mention:n\u00e0y']", "action_query_babe_kb"], ["\u0110\u00fang r \u1ea1", "D\u1ea1, v\u00e2ng \u1ea1. ", "agree", null, "utter_agree"], ["url", "B\u1ea1n \u0111ang t\u00ecm ki\u1ebfm th\u00f4ng tin g\u00ec \u1ea1?", "send_link", "url", "action_handle_send_link_only"], ["E \u01a1i c\u00f2n gi\u1ea5y kh\u00f4 n\u00e0y k?", "Kh\u0103n kh\u00f4 \u0111a n\u0103ng MIPBI 600gr  hi\u1ec7n h\u1ebft h\u00e0ng m\u1eddi b\u1ea1-<br> n tham kh\u1ea3o c\u00e1c s\u1ea3n ph\u1ea9m kh\u00e1c c\u1ee7a shop\nRecommend <-<br>", "query_knowledge_base", "['object_type:khan','mention:n\u00e0y']", "action_query_babe_kb"], ["url", "B\u1ea1n \u0111ang t\u00ecm ki\u1ebfm th\u00f4ng tin g\u00ec \u1ea1?", "send_link", "url", "action_handle_send_link_only"], ["Bn v\u1eady shop \u01a1i", "S\u1ea3n ph\u1ea9m  B\u1ea2NG V\u1ebc HOLLA 2 in 1  hi\u1ec7n shop \u0111ang c\u00f3 -<br> gi\u00e1: 830,000 VND (gi\u00e1 g\u1ed1c 1,090,000 VND).\nB\u1ea1n tham-<br>", "query_knowledge_base", "['attribute:price']", "action_query_babe_kb"], ["C\u00f3 tr\u00ean shopee k shop", "D\u1ea1 m\u1eddi b\u1ea1n tham kh\u1ea3o s\u1ea3n ph\u1ea9m B\u1ea2NG V\u1ebc HOLLA 2 in 1-<br>", "query_knowledge_base", "['attribute:link']", "action_query_babe_kb"], ["url", "B\u1ea1n \u0111ang t\u00ecm ki\u1ebfm th\u00f4ng tin g\u00ec \u1ea1?", "send_link", "url", "action_handle_send_link_only"], ["Bn v\u1eady shop \u01a1i", "S\u1ea3n ph\u1ea9m  B\u1ea2NG V\u1ebc HOLLA 2 in 1  hi\u1ec7n shop \u0111ang c\u00f3 -<br> gi\u00e1: 830,000 VND (gi\u00e1 g\u1ed1c 1,090,000 VND).\nB\u1ea1n tham-<br>", "query_knowledge_base", "['attribute:price']", "action_query_babe_kb"], ["B\u1ea3o h\u00e0nh bao l\u00e2u \u1ea1", "\"D\u1ea1 B\u1ea2NG V\u1ebc HOLLA 2 in 1 b\u1ea3o h\u00e0nh 12 th\u00e1ng \u1ea1. {ch\u00ed-<br>", "query_knowledge_base", "['attribute:guarantee']", "action_query_babe_kb"], ["url", "B\u1ea1n \u0111ang t\u00ecm ki\u1ebfm th\u00f4ng tin g\u00ec \u1ea1?", "send_link", "url", "action_handle_send_link_only"], ["B\u1ed9 n\u00e0y bn shop", "S\u1ea3n ph\u1ea9m  B\u1ea2NG V\u1ebc HOLLA 2 in 1  hi\u1ec7n shop \u0111ang c\u00f3 -<br> gi\u00e1: 830,000 VND (gi\u00e1 g\u1ed1c 1,090,000 VND).\nB\u1ea1n tham-<br>", "query_knowledge_base", "['mention:b\u1ed9 n\u00e0y', 'attribute:price']", "action_query_babe_kb"], ["S\u1ea3n xu\u1ea5t \u1edf \u0111\u00e2u \u1ea1", "D\u1ea1 B\u1ea2NG V\u1ebc HOLLA 2 in 1 c\u00f3 xu\u1ea5t x\u1ee9 t\u1eeb Trung Qu\u1ed1c \u1ea1-<br>", "query_knowledg ...
